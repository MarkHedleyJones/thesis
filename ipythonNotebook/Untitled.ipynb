# %%
# %pylab inline
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xs = [x for x in range(100)]
xs = list(map(lambda x: x/10.0, xs))
sats = [8e-5, 0.2e-5]
ns = [0.9, 0.5]
for sat in sats:
    for n in ns:
       plt.plot(xs, list(map(lambda x: sat * math.exp(x/n),xs)), label="sat="+str(sat)+", n="+str(n))
plt.gca().set_ylim(0,0.1)
# plt.gca().set_xlim(0,10)
plt.gca().legend(loc=0)
